# %% [markdown]
# # New pandas task

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Q-1

# %%
df = pd.read_csv('first_assignment.csv')
df
# Out:
#    student_id             name  age  gender        department  marks_subject1  \
# 0           1         John Doe   18    Male  Computer Science              85
# 1           2       Jane Smith   19  Female        Electrical              88
# 2           3     Mary Johnson   18  Female        Mechanical              90
# 3           4   James Williams   20    Male             Civil              75
# 4           5   Patricia Brown   19  Female  Computer Science              92
# 5           6    Michael Davis   18    Male        Electrical              80
# 6           7  Jennifer Miller   19  Female        Mechanical              85
# 7           8   William Wilson   20    Male             Civil              78
# 8           9      Linda Moore   18  Female  Computer Science              88
# 9          10    Robert Taylor   19    Male        Electrical              95
#
#    marks_subject2  marks_subject3
# 0              78              92
# 1              79              85
# 2              88              76
# 3              85              89
# 4              91              83
# 5              76              85
# 6              82              90
# 7              89              94
# 8              84              78
# 9              87              92

# %% [markdown]
# Q-2

# %%
df.head()
# Out:
#    student_id            name  age  gender        department  marks_subject1  \
# 0           1        John Doe   18    Male  Computer Science              85
# 1           2      Jane Smith   19  Female        Electrical              88
# 2           3    Mary Johnson   18  Female        Mechanical              90
# 3           4  James Williams   20    Male             Civil              75
# 4           5  Patricia Brown   19  Female  Computer Science              92
#
#    marks_subject2  marks_subject3
# 0              78              92
# 1              79              85
# 2              88              76
# 3              85              89
# 4              91              83

# %% [markdown]
# Q-3

# %%
print(df.columns.to_list())
# Out:
# ['student_id', 'name', 'age', 'gender', 'department', 'marks_subject1', 'marks_subject2', 'marks_subject3']

# %% [markdown]
# Q-4

# %%
df.dtypes
# Out:
# student_id         int64
# name              object
# age                int64
# gender            object
# department        object
# marks_subject1     int64
# marks_subject2     int64
# marks_subject3     int64
# dtype: object

# %% [markdown]
# Q-5

# %%
df.describe()
# Out:
#        student_id        age  marks_subject1  marks_subject2  marks_subject3
# count    10.00000  10.000000       10.000000       10.000000       10.000000
# mean      5.50000  18.800000       85.600000       83.900000       86.400000
# std       3.02765   0.788811        6.345602        5.043147        6.095536
# min       1.00000  18.000000       75.000000       76.000000       76.000000
# 25%       3.25000  18.000000       81.250000       79.750000       83.500000
# 50%       5.50000  19.000000       86.500000       84.500000       87.000000
# 75%       7.75000  19.000000       89.500000       87.750000       91.500000
# max      10.00000  20.000000       95.000000       91.000000       94.000000

# %% [markdown]
# Q-6

# %%
df[df["department"] == "Computer Science"]
# Out:
#    student_id            name  age  gender        department  marks_subject1  \
# 0           1        John Doe   18    Male  Computer Science              85
# 4           5  Patricia Brown   19  Female  Computer Science              92
# 8           9     Linda Moore   18  Female  Computer Science              88
#
#    marks_subject2  marks_subject3
# 0              78              92
# 4              91              83
# 8              84              78

# %% [markdown]
# Q-7

# %%
df[[ 'marks_subject1', 'marks_subject2', 'marks_subject3']].mean()
# Out:
# marks_subject1    85.6
# marks_subject2    83.9
# marks_subject3    86.4
# dtype: float64

# %% [markdown]
# Q-8

# %%
df['total_marks'] = df[[ 'marks_subject1', 'marks_subject2', 'marks_subject3']].apply(lambda x: sum(x),axis=1)
df
# Out:
#    student_id             name  age  gender        department  marks_subject1  \
# 0           1         John Doe   18    Male  Computer Science              85
# 1           2       Jane Smith   19  Female        Electrical              88
# 2           3     Mary Johnson   18  Female        Mechanical              90
# 3           4   James Williams   20    Male             Civil              75
# 4           5   Patricia Brown   19  Female  Computer Science              92
# 5           6    Michael Davis   18    Male        Electrical              80
# 6           7  Jennifer Miller   19  Female        Mechanical              85
# 7           8   William Wilson   20    Male             Civil              78
# 8           9      Linda Moore   18  Female  Computer Science              88
# 9          10    Robert Taylor   19    Male        Electrical              95
#
#    marks_subject2  marks_subject3  total_marks
# 0              78              92          255
# 1              79              85          252
# 2              88              76          254
# 3              85              89          249
# 4              91              83          266
# 5              76              85          241
# 6              82              90          257
# 7              89              94          261
# 8              84              78          250
# 9              87              92          274

# %% [markdown]
# Q-9

# %%
df['total_marks'].sort_values(ascending=False)
# Out:
# 9    274
# 4    266
# 7    261
# 6    257
# 0    255
# 2    254
# 1    252
# 8    250
# 3    249
# 5    241
# Name: total_marks, dtype: int64

# %% [markdown]
# Q-10

# %%
df.groupby('department')[["marks_subject1","marks_subject2","marks_subject3"]].sum()
# Out:
#                   marks_subject1  marks_subject2  marks_subject3
# department
# Civil                        153             174             183
# Computer Science             265             253             253
# Electrical                   263             242             262
# Mechanical                   175             170             166

# %% [markdown]
# Q-11

# %%
df.sort_values(by='marks_subject1',ascending=False).head(1)
# Out:
#    student_id           name  age gender  department  marks_subject1  \
# 9          10  Robert Taylor   19   Male  Electrical              95
#
#    marks_subject2  marks_subject3  total_marks
# 9              87              92          274

# %% [markdown]
# Q-12

# %%
Male = df.loc[df['gender'] == 'Male'].count()[0]
print("No. of males = ",Male,"\n\n")
male_dataframe = df.loc[df['gender'] == 'Male']
male_dataframe
# Out:
# No. of males =  5
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22028\3039894753.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Male = df.loc[df['gender'] == 'Male'].count()[0]
#    student_id            name  age gender        department  marks_subject1  \
# 0           1        John Doe   18   Male  Computer Science              85
# 3           4  James Williams   20   Male             Civil              75
# 5           6   Michael Davis   18   Male        Electrical              80
# 7           8  William Wilson   20   Male             Civil              78
# 9          10   Robert Taylor   19   Male        Electrical              95
#
#    marks_subject2  marks_subject3  total_marks
# 0              78              92          255
# 3              85              89          249
# 5              76              85          241
# 7              89              94          261
# 9              87              92          274

# %%
Female = df.loc[df['gender'] == 'Female'].count()[0]
print("No.of Females = " , Female,"\n\n")
female_dataframe = df.loc[df['gender'] == 'Female']
female_dataframe
# Out:
# No.of Females =  5
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22028\1854451478.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Female = df.loc[df['gender'] == 'Female'].count()[0]
#    student_id             name  age  gender        department  marks_subject1  \
# 1           2       Jane Smith   19  Female        Electrical              88
# 2           3     Mary Johnson   18  Female        Mechanical              90
# 4           5   Patricia Brown   19  Female  Computer Science              92
# 6           7  Jennifer Miller   19  Female        Mechanical              85
# 8           9      Linda Moore   18  Female  Computer Science              88
#
#    marks_subject2  marks_subject3  total_marks
# 1              79              85          252
# 2              88              76          254
# 4              91              83          266
# 6              82              90          257
# 8              84              78          250

# %%
labels = ['males' , 'females']
plt.pie([Male,Female] , labels=labels , autopct='%.1f%%')
plt.title("Gender percentage of class")
plt.show()

# %% [markdown]
# Q-13

# %%
df[df['age']>=19]
# Out:
#    student_id             name  age  gender        department  marks_subject1  \
# 1           2       Jane Smith   19  Female        Electrical              88
# 3           4   James Williams   20    Male             Civil              75
# 4           5   Patricia Brown   19  Female  Computer Science              92
# 6           7  Jennifer Miller   19  Female        Mechanical              85
# 7           8   William Wilson   20    Male             Civil              78
# 9          10    Robert Taylor   19    Male        Electrical              95
#
#    marks_subject2  marks_subject3  total_marks
# 1              79              85          252
# 3              85              89          249
# 4              91              83          266
# 6              82              90          257
# 7              89              94          261
# 9              87              92          274

# %% [markdown]
# Q-14

# %%
pd.isna(df)
# Out:
#    student_id   name    age  gender  department  marks_subject1  \
# 0       False  False  False   False       False           False
# 1       False  False  False   False       False           False
# 2       False  False  False   False       False           False
# 3       False  False  False   False       False           False
# 4       False  False  False   False       False           False
# 5       False  False  False   False       False           False
# 6       False  False  False   False       False           False
# 7       False  False  False   False       False           False
# 8       False  False  False   False       False           False
# 9       False  False  False   False       False           False
#
#    marks_subject2  marks_subject3  total_marks
# 0           False           False        False
# 1           False           False        False
# 2           False           False        False
# 3           False           False        False
# 4           False           False        False
# 5           False           False        False
# 6           False           False        False
# 7           False           False        False
# 8           False           False        False
# 9           False           False        False

# %% [markdown]
# Q-15

# %%
CSE_students = df.loc[df['department'] == "Computer Science"].count()[0]
print("No. of students in CSE = ", CSE_students,"\n\n")
Computer_Science = df.loc[df['department'] == "Computer Science"]
Computer_Science
# Out:
# No. of students in CSE =  3
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22028\1451899308.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   CSE_students = df.loc[df['department'] == "Computer Science"].count()[0]
#    student_id            name  age  gender        department  marks_subject1  \
# 0           1        John Doe   18    Male  Computer Science              85
# 4           5  Patricia Brown   19  Female  Computer Science              92
# 8           9     Linda Moore   18  Female  Computer Science              88
#
#    marks_subject2  marks_subject3  total_marks
# 0              78              92          255
# 4              91              83          266
# 8              84              78          250

# %%
Electrical_students = df.loc[df['department'] == "Electrical"].count()[0]
print("No. of students in Electical = ", Electrical_students,"\n\n")
Electrical = df.loc[df['department'] == "Electrical"]
Electrical
# Out:
# No. of students in Electical =  3
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22028\1573273722.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Electrical_students = df.loc[df['department'] == "Electrical"].count()[0]
#    student_id           name  age  gender  department  marks_subject1  \
# 1           2     Jane Smith   19  Female  Electrical              88
# 5           6  Michael Davis   18    Male  Electrical              80
# 9          10  Robert Taylor   19    Male  Electrical              95
#
#    marks_subject2  marks_subject3  total_marks
# 1              79              85          252
# 5              76              85          241
# 9              87              92          274

# %%
Mechanical_students = df.loc[df['department'] == "Mechanical"].count()[0]
print("No. of students in Mechanical = ",Mechanical_students,"\n\n")
Mechanical = df.loc[df['department'] == "Mechanical"]
Mechanical
# Out:
# No. of students in Mechanical =  2
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22028\4133063719.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Mechanical_students = df.loc[df['department'] == "Mechanical"].count()[0]
#    student_id             name  age  gender  department  marks_subject1  \
# 2           3     Mary Johnson   18  Female  Mechanical              90
# 6           7  Jennifer Miller   19  Female  Mechanical              85
#
#    marks_subject2  marks_subject3  total_marks
# 2              88              76          254
# 6              82              90          257

# %%
Civil_students = df.loc[df['department'] == "Civil"].count()[0]
print("No. of students in Civil = ",Civil_students,"\n\n")
Civil = df.loc[df['department'] == "Civil"]
Civil
# Out:
# No. of students in Civil =  2
# C:\Users\Hp\AppData\Local\Temp\ipykernel_22028\3942259342.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   Civil_students = df.loc[df['department'] == "Civil"].count()[0]
#    student_id            name  age gender department  marks_subject1  \
# 3           4  James Williams   20   Male      Civil              75
# 7           8  William Wilson   20   Male      Civil              78
#
#    marks_subject2  marks_subject3  total_marks
# 3              85              89          249
# 7              89              94          261

# %% [markdown]
# Q-16

# %%
Computer_Science.sort_values(by = 'total_marks',ascending=False).head(1)
# Out:
#    student_id            name  age  gender        department  marks_subject1  \
# 4           5  Patricia Brown   19  Female  Computer Science              92
#
#    marks_subject2  marks_subject3  total_marks
# 4              91              83          266

# %%
Electrical.sort_values(by = 'total_marks',ascending=False).head(1)
# Out:
#    student_id           name  age gender  department  marks_subject1  \
# 9          10  Robert Taylor   19   Male  Electrical              95
#
#    marks_subject2  marks_subject3  total_marks
# 9              87              92          274

# %%
Mechanical.sort_values(by = 'total_marks',ascending=False).head(1)
# Out:
#    student_id             name  age  gender  department  marks_subject1  \
# 6           7  Jennifer Miller   19  Female  Mechanical              85
#
#    marks_subject2  marks_subject3  total_marks
# 6              82              90          257

# %%
Civil.sort_values(by = 'total_marks',ascending=False).head(1)
# Out:
#    student_id            name  age gender department  marks_subject1  \
# 7           8  William Wilson   20   Male      Civil              78
#
#    marks_subject2  marks_subject3  total_marks
# 7              89              94          261

# %% [markdown]
# Q-17

# %%
df[df['marks_subject2']>80].merge(df[df['marks_subject2']<90]).sort_values(by="marks_subject2",ascending=True)
# Out:
#    student_id             name  age  gender        department  marks_subject1  \
# 2           7  Jennifer Miller   19  Female        Mechanical              85
# 4           9      Linda Moore   18  Female  Computer Science              88
# 1           4   James Williams   20    Male             Civil              75
# 5          10    Robert Taylor   19    Male        Electrical              95
# 0           3     Mary Johnson   18  Female        Mechanical              90
# 3           8   William Wilson   20    Male             Civil              78
#
#    marks_subject2  marks_subject3  total_marks
# 2              82              90          257
# 4              84              78          250
# 1              85              89          249
# 5              87              92          274
# 0              88              76          254
# 3              89              94          261

# %% [markdown]
# Q-18

# %%
df['normalized_marks'] = df[['marks_subject1']].apply(lambda x: (x - x.min()) / (x.max() - x.min()))
df
# Out:
#    student_id             name  age  gender        department  marks_subject1  \
# 0           1         John Doe   18    Male  Computer Science              85
# 1           2       Jane Smith   19  Female        Electrical              88
# 2           3     Mary Johnson   18  Female        Mechanical              90
# 3           4   James Williams   20    Male             Civil              75
# 4           5   Patricia Brown   19  Female  Computer Science              92
# 5           6    Michael Davis   18    Male        Electrical              80
# 6           7  Jennifer Miller   19  Female        Mechanical              85
# 7           8   William Wilson   20    Male             Civil              78
# 8           9      Linda Moore   18  Female  Computer Science              88
# 9          10    Robert Taylor   19    Male        Electrical              95
#
#    marks_subject2  marks_subject3  total_marks  normalized_marks
# 0              78              92          255              0.50
# 1              79              85          252              0.65
# 2              88              76          254              0.75
# 3              85              89          249              0.00
# 4              91              83          266              0.85
# 5              76              85          241              0.25
# 6              82              90          257              0.50
# 7              89              94          261              0.15
# 8              84              78          250              0.65
# 9              87              92          274              1.00

# %% [markdown]
# Q-19

# %%
df.pivot_table(index = 'gender',values=['marks_subject1', 'marks_subject2', 'marks_subject3'], aggfunc='mean')
# Out:
#         marks_subject1  marks_subject2  marks_subject3
# gender
# Female            88.6            84.8            82.4
# Male              82.6            83.0            90.4

# %% [markdown]
# Q-20

# %%
df.to_csv("Corrected Student records.csv")
